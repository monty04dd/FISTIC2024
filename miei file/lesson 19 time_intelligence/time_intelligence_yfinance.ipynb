# %%
import yfinance as yf
import pandas as pd

# %%
apple= yf.Ticker("aapl")
apple
# Out:
# yfinance.Ticker object <AAPL>

# %%
apple_data = yf.download('AAPL', start='2000-01-01')
apple_data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2000-01-03    0.843076    0.847313    0.765877    0.789884  535796800
# 2000-01-04    0.771997    0.833191    0.762111    0.815304  512377600
# 2000-01-05    0.783293    0.832720    0.775762    0.781410  778321600
# 2000-01-06    0.715508    0.805889    0.715508    0.799299  767972800
# 2000-01-07    0.749401    0.760699    0.719275    0.726806  460734400
# ...                ...         ...         ...         ...        ...
# 2025-01-13  234.399994  234.669998  229.720001  233.529999   49630700
# 2025-01-14  233.279999  236.119995  232.470001  234.750000   39435300
# 2025-01-15  237.869995  238.960007  234.429993  234.639999   39832000
# 2025-01-16  228.259995  238.009995  228.029999  237.350006   71759100
# ...

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Scarica i dati di Apple
apple_data = yf.download('AAPL', start='1980-01-01')

# Mantieni la data come indice
# Resample annuale e calcola la media
resampled_data = apple_data.resample('A').mean()

# Aggiungi una colonna per l'anno
resampled_data['Year'] = resampled_data.index.year

# Crea un istogramma con gli anni come colonne
resampled_data.set_index('Year')['Volume'].plot(kind='bar', figsize=(12, 6))
plt.title('Volume Annuale per Anno (Apple)')
plt.xlabel('Anno')
plt.ylabel('Volume medio')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\lucam\AppData\Local\Temp\ipykernel_22440\2606056976.py:10: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   resampled_data = apple_data.resample('A').mean()

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Scarica i dati di Apple
apple_data = yf.download('AAPL', start='1980-01-01')

# Mantieni la data come indice
# Resample annuale e calcola la media
resampled_data = apple_data.resample('YE').mean()

# Aggiungi una colonna per l'anno
resampled_data['Year'] = resampled_data.index.year

# Crea un istogramma con i valori reali
fig, ax = plt.subplots(figsize=(12, 6))
resampled_data.set_index('Year')['Volume'].plot(kind='line', ax=ax)

# Etichette del grafico
ax.set_title('Volume Medio Annuale (Apple)')
ax.set_xlabel('Anno')
ax.set_ylabel('Volume Medio Giornaliero')

# Mostra i valori numerici reali senza notazione scientifica
ax.get_yaxis().get_major_formatter().set_scientific(False)

# Ruota i valori sull'asse X per maggiore leggibilità
plt.xticks(rotation=45)

plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Scarica i dati di Apple
apple_data = yf.download('AAPL', start='2024-01-01')

# Mantieni la data come indice
# Resample annuale e calcola la media
resampled_data = apple_data.resample('M').mean()

# Aggiungi una colonna per l'anno
resampled_data['Year'] = resampled_data.index.month

# Crea un istogramma con i valori reali
fig, ax = plt.subplots(figsize=(12, 6))
resampled_data.set_index('Year')['Volume'].plot(kind='bar', ax=ax)

# Etichette del grafico
ax.set_title('Volume Medio mensile (Apple)')
ax.set_xlabel('mese')
ax.set_ylabel('Volume Medio Giornaliero')

# Mostra i valori numerici reali senza notazione scientifica
ax.get_yaxis().get_major_formatter().set_scientific(False)

# Ruota i valori sull'asse X per maggiore leggibilità
plt.xticks(rotation=45)

plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\lucam\AppData\Local\Temp\ipykernel_22440\1819341458.py:10: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   resampled_data = apple_data.resample('M').mean()

# %%
resampled_data = apple_data.resample('M').mean()
resampled_data
# Out:
# C:\Users\lucam\AppData\Local\Temp\ipykernel_22440\3422809117.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   resampled_data = apple_data.resample('M').mean()
# Price            Close        High         Low        Open        Volume
# Ticker            AAPL        AAPL        AAPL        AAPL          AAPL
# Date
# 2024-01-31  186.809102  188.077651  185.192262  186.682580  5.653425e+07
# 2024-02-29  184.037743  185.300291  182.300534  183.931171  5.808135e+07
# 2024-03-31  172.073873  173.691022  170.645042  172.166040  7.163914e+07
# 2024-04-30  168.993062  170.674704  167.840870  169.049675  5.662350e+07
# 2024-05-31  185.788820  187.319573  184.562155  185.934226  6.075171e+07
# 2024-06-30  205.798267  208.565176  203.460391  205.530449  9.073603e+07
# 2024-07-31  224.092420  226.160024  221.529572  224.091511  5.241363e+07
# 2024-08-31  221.316173  223.393076  218.423926  220.435155  5.103032e+07
# ...

# %%
resampled_data = apple_data.resample('BMS').mean()
resampled_data
# Out:
# Price            Close        High         Low        Open        Volume
# Ticker            AAPL        AAPL        AAPL        AAPL          AAPL
# Date
# 2024-01-01  186.809102  188.077651  185.192262  186.682580  5.653425e+07
# 2024-02-01  184.037743  185.300291  182.300534  183.931171  5.808135e+07
# 2024-03-01  172.073873  173.691022  170.645042  172.166040  7.163914e+07
# 2024-04-01  168.993062  170.674704  167.840870  169.049675  5.662350e+07
# 2024-05-01  185.788820  187.319573  184.562155  185.934226  6.075171e+07
# 2024-06-03  205.798267  208.565176  203.460391  205.530449  9.073603e+07
# 2024-07-01  224.092420  226.160024  221.529572  224.091511  5.241363e+07
# 2024-08-01  221.316173  223.393076  218.423926  220.435155  5.103032e+07
# 2024-09-02  223.512093  225.341079  221.213121  223.483624  6.160702e+07
# 2024-10-01  229.803258  231.403671  227.838464  229.903147  4.046678e+07
# 2024-11-01  227.749033  229.011124  225.565179  226.661451  4.458203e+07
# ...
